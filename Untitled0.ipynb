# %% [markdown]
# <a href="https://colab.research.google.com/github/mauro2082/ApiStarwars/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os  # esta libreria nos permite trabajar con archivos, carpetas, directorios

# %%
import glob # esta libreria nos permite buscar en los archivos, carpetas, directorios

# %%
from IPython.display import Image # esta libreria nos permite visualizar imagenes

# %%
from IPython import display # esta libreria nos permite visualizar imagenes

# %%
display.clear_output(wait=True) # esta libreria nos permite limpiar la salida de la celda

# %%
# !nvidia-smi
# Out:
# Wed Mar 12 14:15:49 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics

# %%
import ultralytics # verificar libreria
ultralytics.checks() # verificar libr
# Out:
# Ultralytics 8.3.88 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 40.9/112.6 GB disk)

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="sgJaAPi7KesanF10Nurl")
project = rf.workspace("safety-irdet").project("safetyrock")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to safetyRock-1 in yolov8:: 100%|██████████| 924/924 [00:00<00:00, 6255.63it/s]

# %%
# %cd {HOME}
# Out:
# /content

# %%
# %cd {dataset.location}
# Out:
# /content/datasets/safetyRock-1

# %%
# %cd {HOME}
# Out:
# /content

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/content/datasets/safetyRock-1/data.yaml epochs=100 imgsz=640 batch=16 lr0=0.001
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 323MB/s]
# Ultralytics 8.3.88 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls {HOME}//runs/detect/train
# Out:
# args.yaml					     PR_curve.png	  train_batch2072.jpg
# confusion_matrix_normalized.png			     R_curve.png	  train_batch2.jpg
# confusion_matrix.png				     results.csv	  val_batch0_labels.jpg
# events.out.tfevents.1741790001.539d5560e095.12110.0  results.png	  val_batch0_pred.jpg
# F1_curve.png					     train_batch0.jpg	  val_batch1_labels.jpg
# labels_correlogram.jpg				     train_batch1.jpg	  val_batch1_pred.jpg
# labels.jpg					     train_batch2070.jpg  weights
# P_curve.png					     train_batch2071.jpg

# %%
# %cd {HOME}
# Out:
# /content

# %%
from IPython.display import Image

Image(filename='/content/runs/detect/train/confusion_matrix.png', width=900)

# %%
# %cd {HOME}
from IPython.display import Image
Image(filename='/content/runs/detect/train/results.png',width=600)
# Out:
# /content

# %%
# %cd {HOME}
from IPython.display import Image
Image(filename='/content/runs/detect/train/val_batch0_pred.jpg',width=600)
# Out:
# /content

# %%
from google.colab import files
files.download('/content/runs/detect/train/weights/best.pt')

# %%
# %cd {HOME}

# !yolo task=detect mode=val model=/content//runs/detect/train/weights/best.pt data=/content/datasets/safetyRock-1/data.yaml
# Out:
# /content
# Ultralytics 8.3.88 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/datasets/safetyRock-1/valid/labels.cache... 59 images, 7 backgrounds, 0 corrupt: 100% 59/59 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:02<00:00,  1.56it/s]
#                    all         59         81      0.828      0.443       0.55      0.414
#                 roca_s          4          4          1          0      0.306      0.223
#                 rock_b          7          7       0.79      0.543      0.559      0.472
#                 rock_m         45         70      0.694      0.786      0.785      0.547
# Speed: 5.3ms preprocess, 22.5ms inference, 0.0ms loss, 3.8ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#testeo del modelo con el dataset

# %cd {HOME}

# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# Ultralytics 8.3.88 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/30 /content/datasets/safetyRock-1/test/images/Snapshot_103_JPG.rf.07226bf941b9875df5fe8da39026d068.jpg: 640x640 1 rock_m, 37.0ms
# image 2/30 /content/datasets/safetyRock-1/test/images/Snapshot_111_JPG.rf.c3f6dc338d23df62fad47d234cf58b4e.jpg: 640x640 1 rock_m, 37.0ms
# image 3/30 /content/datasets/safetyRock-1/test/images/Snapshot_119_JPG.rf.8b8f7c7ebc6aeee597312bc97f51b9c8.jpg: 640x640 1 rock_m, 36.9ms
# image 4/30 /content/datasets/safetyRock-1/test/images/Snapshot_137_JPG.rf.394d385c4736ea1224da29e899ee5952.jpg: 640x640 2 rock_ms, 36.9ms
# image 5/30 /content/datasets/safetyRock-1/test/images/Snapshot_143_JPG.rf.686d9b62d7426925651b8d0760e85065.jpg: 640x640 2 rock_ms, 37.0ms
# ...

# %%
for image_path in glob.glob('/content/runs/detect/predict/*.jpg')[:6]:
  display.display(Image(filename=image_path,width=600))
  print("\n")
