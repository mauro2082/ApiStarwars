# %% [markdown]
# <a href="https://colab.research.google.com/github/mauro2082/ApiStarwars/blob/master/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# Out:
# /content

# %%
import os  # esta libreria nos permite trabajar con archivos, carpetas, directorios
import glob # esta libreria nos permite buscar en los archivos, carpetas, directorios
from IPython.display import Image # esta libreria nos permite visualizar imagenes
from IPython import display # esta libreria nos permite visualizar imagenes
display.clear_output(wait=True) # esta libreria nos permite limpiar la salida de la celda

# %%
HOME = os.getcwd()
print(HOME)   # Podemos obtener la ruta de trabajo actual
# Out:
# /content

# %%
# !pip install ultralytics==8.0.20
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.2/261.2 kB 19.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 74.6 MB/s eta 0:00:00
# ...

# %%
# Crear la carpeta datasets si no existe

dataset_path = os.path.join(HOME, 'datasets')
if not os.path.exists(dataset_path):
    os.makedirs(dataset_path)
    print(f"Directorio 'datasets' creado en {dataset_path}")
else:
    print(f"El directorio 'datasets' ya existe en {dataset_path}")

# Cambiar al directorio datasets
# %cd {dataset_path}
# Out:
# El directorio 'datasets' ya existe en /content/datasets
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="or9fJpqV2p5sYP0BQ7Di")
project = rf.workspace("objet-detect-yolov5").project("eep_detection-u9bbd")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to EEP_Detection-1 in yolov8:: 100%|██████████| 6482/6482 [00:01<00:00, 4958.08it/s]

# %%
# %cd {HOME}
# Out:
# /content

# %%
# %cd {dataset.location}
# Out:
# /content/datasets/EEP_Detection-1

# %%
# %cd {HOME}
# Out:
# /content

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/content/datasets/EEP_Detection-1/data.yaml epochs=50 imgsz=640
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#                 helmet        647        765      0.934      0.958       0.98       0.76
#                 shield        647         25      0.926       0.52      0.648      0.369
#                 jacked        647        580      0.891      0.891       0.94      0.723
#              dust mask        647        314      0.966      0.916      0.964      0.667
#               eye wear        647        149      0.895      0.685      0.834      0.452
#                  glove        647        645      0.958      0.888       0.95      0.684
#                  boots        647        596      0.971      0.973      0.991      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# ...
